# %% [markdown]
# <a href="https://colab.research.google.com/github/Andreluizfc/AI-study/blob/master/exercises/neural_networks/Fast_Style_Transfer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install moviepy

# %%
# !python -c "import imageio; imageio.plugins.ffmpeg.download()"
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.

# %%
# !git clone https://github.com/lengstrom/fast-style-transfer.git
# Out:
# Cloning into 'fast-style-transfer'...
# remote: Enumerating objects: 235, done.
# remote: Total 235 (delta 0), reused 0 (delta 0), pack-reused 235
# Receiving objects: 100% (235/235), 11.02 MiB | 8.27 MiB/s, done.
# Resolving deltas: 100% (110/110), done.

# %%
# !wget https://d17h27t6h515a5.cloudfront.net/topher/2017/January/587d1865_rain-princess/rain-princess.ckpt
# !wget http://video.udacity-data.com.s3.amazonaws.com/topher/2017/January/588aa89d_wave/wave.ckpt

# %%
# !wget https://upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Panthera_onca_at_the_Toronto_Zoo_2.jpg/1920px-Panthera_onca_at_the_Toronto_Zoo_2.jpg

# %%
from PIL import Image
import cv2
import requests
import numpy as np
import matplotlib.pyplot as plt

# %%
# Auxiliary functions for image

def convert_from_cv2_to_image(img: np.ndarray) -> Image:
    return Image.fromarray(img)


def convert_from_image_to_cv2(img: Image) -> np.ndarray:
    return np.asarray(img)


def img_from_url(url):
    img = Image.open(requests.get(url, stream=True).raw)
    return img

# %%
# !cd fast-style-transfer && python evaluate.py --checkpoint /content/wave.ckpt --in-path /content/panther.jpg --out-path /content/panther_wave.jpg

# %%
pil_img = Image.open('/content/panther_wave.jpg')

plt.figure(figsize=([15, 15]))
plt.imshow(pil_img)

# %%
# !cd fast-style-transfer && python evaluate.py --checkpoint /content/rain-princess.ckpt --in-path /content/panther.jpg --out-path /content/panther_rain.jpg

# %%
pil_img = Image.open('/content/panther_rain.jpg')

plt.figure(figsize=([15, 15]))
plt.imshow(pil_img)
